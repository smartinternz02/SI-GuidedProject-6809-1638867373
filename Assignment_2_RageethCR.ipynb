# %% [markdown]
# # importing data 'titanic'

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
dataset=sns.load_dataset('titanic')

# %%
dataset
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male   NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
dataset.isnull().any()
# Out:
# survived       False
# pclass         False
# sex            False
# age             True
# sibsp          False
# parch          False
# fare           False
# embarked        True
# class          False
# who            False
# adult_male     False
# deck            True
# embark_town     True
# alive          False
# alone          False
# dtype: bool

# %% [markdown]
# # checking the number of missing values

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null category
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
dataset.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# # handling the missing values

# %%
dataset['age'].fillna(dataset['age'].median(), axis=0, inplace=True)

# %%
dataset
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male  28.0      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
dataset.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
dataset.drop(columns=['class','who','adult_male','deck','embark_town','alive','alone'], axis=0, inplace=True)

# %%
dataset
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked
# 0           0       3    male  22.0      1      0    7.2500        S
# 1           1       1  female  38.0      1      0   71.2833        C
# 2           1       3  female  26.0      0      0    7.9250        S
# 3           1       1  female  35.0      1      0   53.1000        S
# 4           0       3    male  35.0      0      0    8.0500        S
# 5           0       3    male  28.0      0      0    8.4583        Q
# 6           0       1    male  54.0      0      0   51.8625        S
# 7           0       3    male   2.0      3      1   21.0750        S
# 8           1       3  female  27.0      0      2   11.1333        S
# 9           1       2  female  14.0      1      0   30.0708        C
# 10          1       3  female   4.0      1      1   16.7000        S
# 11          1       1  female  58.0      0      0   26.5500        S
# 12          0       3    male  20.0      0      0    8.0500        S
# ...

# %%
dataset[dataset.isnull().any(axis=1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked
# 61          1       1  female  38.0      0      0  80.0      NaN
# 829         1       1  female  62.0      0      0  80.0      NaN

# %%
missing_embarked = dataset['embarked'].mode()[0]

# %%
missing_embarked
# Out:
# 'S'

# %%
dataset['embarked'].fillna(missing_embarked,inplace = True)

# %%
dataset.isnull().any()
# Out:
# survived    False
# pclass      False
# sex         False
# age         False
# sibsp       False
# parch       False
# fare        False
# embarked    False
# dtype: bool

# %%
dataset.loc[[61,829]]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked
# 61          1       1  female  38.0      0      0  80.0        S
# 829         1       1  female  62.0      0      0  80.0        S

# %%
dataset
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked
# 0           0       3    male  22.0      1      0    7.2500        S
# 1           1       1  female  38.0      1      0   71.2833        C
# 2           1       3  female  26.0      0      0    7.9250        S
# 3           1       1  female  35.0      1      0   53.1000        S
# 4           0       3    male  35.0      0      0    8.0500        S
# 5           0       3    male  28.0      0      0    8.4583        Q
# 6           0       1    male  54.0      0      0   51.8625        S
# 7           0       3    male   2.0      3      1   21.0750        S
# 8           1       3  female  27.0      0      2   11.1333        S
# 9           1       2  female  14.0      1      0   30.0708        C
# 10          1       3  female   4.0      1      1   16.7000        S
# 11          1       1  female  58.0      0      0   26.5500        S
# 12          0       3    male  20.0      0      0    8.0500        S
# ...

# %%
sns.boxplot(dataset['age'])

# %%
sns.boxplot(dataset['fare'])

# %%
sns.boxplot(dataset['sibsp'])

# %%
sns.boxplot(dataset['parch'])

# %%
dataset.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.361582    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.019697    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
q1= dataset['age'].describe()['25%']
q1
# Out:
# 22.0

# %%
q2= dataset['age'].describe()['75%']
q2
# Out:
# 35.0

# %%
iqr = q2-q1
iqr
# Out:
# 13.0

# %%
lower_boundary = q1 - (1.5*iqr)
lower_boundary
# Out:
# 2.5

# %%
upper_boundary = q2 + (1.5*iqr)
upper_boundary
# Out:
# 54.5

# %%
(dataset[dataset['age']>upper_boundary].shape[0]/dataset['age'].shape[0])*100
# Out:
# 4.713804713804714

# %%
(dataset[dataset['age']<lower_boundary].shape[0]/dataset['age'].shape[0])*100
# Out:
# 2.6936026936026933

# %%
q1= dataset['sibsp'].describe()['25%']
q1
# Out:
# 0.0

# %%
q2= dataset['sibsp'].describe()['75%']
q2
# Out:
# 1.0

# %%
iqr = q2-q1
iqr
# Out:
# 1.0

# %%
lower_boundary = q1 - (1.5*iqr)
lower_boundary
# Out:
# -1.5

# %%
upper_boundary = q2 + (1.5*iqr)
upper_boundary
# Out:
# 2.5

# %%
(dataset[dataset['sibsp']>upper_boundary].shape[0]/dataset['sibsp'].shape[0])*100
# Out:
# 5.16273849607183

# %%
(dataset[dataset['sibsp']<lower_boundary].shape[0]/dataset['sibsp'].shape[0])*100
# Out:
# 0.0

# %%
q1= dataset['parch'].describe()['25%']
q2 = dataset['parch'].describe()['75%']
iqr = q2-q1
iqr
# Out:
# 0.0

# %%
q1= dataset['fare'].describe()['25%']
q2 = dataset['fare'].describe()['75%']
iqr = q2-q1
iqr
# Out:
# 23.0896

# %%
lower_boundary = q1 - (1.5*iqr)
lower_boundary
# Out:
# -26.724

# %%
upper_boundary = q2 + (1.5*iqr)
upper_boundary
# Out:
# 65.6344

# %%
(dataset[dataset['fare']>upper_boundary].shape[0]/dataset['fare'].shape[0])*100
# Out:
# 13.019079685746352

# %%
(dataset[dataset['fare']<lower_boundary].shape[0]/dataset['fare'].shape[0])*100
# Out:
# 0.0

# %%
dataset
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked
# 0           0       3    male  22.0      1      0    7.2500        S
# 1           1       1  female  38.0      1      0   71.2833        C
# 2           1       3  female  26.0      0      0    7.9250        S
# 3           1       1  female  35.0      1      0   53.1000        S
# 4           0       3    male  35.0      0      0    8.0500        S
# 5           0       3    male  28.0      0      0    8.4583        Q
# 6           0       1    male  54.0      0      0   51.8625        S
# 7           0       3    male   2.0      3      1   21.0750        S
# 8           1       3  female  27.0      0      2   11.1333        S
# 9           1       2  female  14.0      1      0   30.0708        C
# 10          1       3  female   4.0      1      1   16.7000        S
# 11          1       1  female  58.0      0      0   26.5500        S
# 12          0       3    male  20.0      0      0    8.0500        S
# ...

# %%
dataset['sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
dataset['embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
freq=dataset['sex'].value_counts()
freq
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
freq.index
# Out:
# Index(['male', 'female'], dtype='object')

# %%
plt.bar(freq.index,freq.values)
plt.xlabel("Sex")
plt.ylabel("people")
plt.title("number of people based on gender")
plt.show()

# %% [markdown]
# # Insights / observations
#
# 1. Bar chart represents more male was boarded in titanic as compared with female.
# 2. Men ranges between around 550 to 580.

# %%
plt.pie(freq.values,labels=freq.index, autopct='%.2f%%')
plt.title('Percentage analysis Male and Female ')
plt.show()

# %% [markdown]
# # Insights / observations
# above same data analysed through pie chart
# 1. Totally titanic was crowded with male as compared with female.
# 2. Almost 64.76% of the passagers is male and only 35.24% are females.

# %%
sns.barplot(data=dataset,x='sex',y='survived')
plt.xlabel("Sex")
plt.ylabel("Survived")
plt.title("Count of survived people based on their sex")
plt.show()

# %% [markdown]
# # Insights / observations
#
# 1. Shows the count of people who survived based on their sex.
# 2. The female has survived more than male.

# %%
sns.barplot(data=dataset,x='pclass',y='survived')
plt.xlabel("pclass")
plt.ylabel("Survived")
plt.title("Count of survived people based on passenger class")
plt.show()

# %% [markdown]
# # Insights / observations
#
# 1. The first class people survived more than second class and third class so it is more safer
# 2. The third class people has survived less compared to the classes.

# %%
sns.scatterplot(data=dataset,x='age',y='survived')
plt.xlabel("Age")
plt.ylabel("Survived")
plt.title("Count of survived people based on passenger age")
plt.show()

# %% [markdown]
# # Insights / observations
# 1. Here depicts that age is not a factor, as it affect equally.

# %%
sns.barplot(data=dataset,x='sibsp',y='survived')
plt.xlabel("sibsp")
plt.ylabel("Survived")
plt.title("Count of survived people based on their sibsp")
plt.show()

# %% [markdown]
# # Insights / observations
# 1. The single sibling / spouse have higher number of survival rate.

# %%
sns.barplot(data=dataset,x='parch',y='survived')
plt.xlabel("Parch")
plt.ylabel("Survived")
plt.title("Count of survived people based on their parch")
plt.show()

# %% [markdown]
# # Insight / observation
# 1. parch(Number of Parents/Children Aboard) number 3 has survived more.
# 2. parch(Number of Parents/Children Aboard) number 5 has survived less.

# %%
sns.violinplot(x ="sex", y ="age", hue ="survived", data = dataset, split = True)
plt.title("Survived analysis based on their age and sex")
plt.show()

# %% [markdown]
# #  Insight / observation
# 1. Survival rate is high for women between the age group 20 to 50.
# 2. Men survival rate decreases when age is increasing.

# %%
sns.catplot(x ='embarked', hue ='survived', kind ='count', col ='pclass', data = dataset)

plt.show()

# %% [markdown]
# # Insight / observation
# 1. The majority of people boarded from Southampton (S).
# 2. The majority of class 3 people boarded from Queenstown (Q).

# %%
dataset=pd.get_dummies(dataset, columns=["sex","embarked"])

# %%
dataset
# Out:
#      survived  pclass   age  sibsp  parch      fare  sex_female  sex_male  \
# 0           0       3  22.0      1      0    7.2500           0         1
# 1           1       1  38.0      1      0   71.2833           1         0
# 2           1       3  26.0      0      0    7.9250           1         0
# 3           1       1  35.0      1      0   53.1000           1         0
# 4           0       3  35.0      0      0    8.0500           0         1
# 5           0       3  28.0      0      0    8.4583           0         1
# 6           0       1  54.0      0      0   51.8625           0         1
# 7           0       3   2.0      3      1   21.0750           0         1
# 8           1       3  27.0      0      2   11.1333           1         0
# 9           1       2  14.0      1      0   30.0708           1         0
# 10          1       3   4.0      1      1   16.7000           1         0
# 11          1       1  58.0      0      0   26.5500           1         0
# ...

# %%
plt.hist(dataset['parch'])
plt.title('Analysis of Parents/children aboard')
plt.xlabel('Parents/children')
plt.ylabel('count')
plt.show()

# %% [markdown]
# # Insights / observations
#
# 1. The majority of passengers is not parents/children.
# 2. Nearly 700 people is not parent/children. Only nearly 110 of population is parents/childrens.

# %%
sns.scatterplot(dataset['pclass'],dataset['fare'])
plt.title('Passenger class Vs Fare of travel')
plt.xlabel('Passenger class')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# # Insights / observations
#
# 1. The fare of travel is depends on passanger class.
# 2. 1st class passangers have a higher fare as compared with 2nd and 3rd.

# %%
sns.distplot(dataset['survived'])
plt.xlabel('Survived')
plt.ylabel('Frequency')
plt.title('Survival rate vs Death rate')
plt.show()

# %% [markdown]
# # Insights / observations
# 1. people survived is less as compared with death rate

# %%
dataset['fare'].value_counts().sort_values(ascending=False).head(20).plot(kind="barh")
plt.xlabel("frequency")
plt.ylabel("fares")
plt.title("Frequency of fares spend")
plt.show()

# %% [markdown]
# # Insights / observations
#
# 1. It depicts different passangers spend different fares.
# 2. Above 40 of passengers spend 8.05 as their travel fare.

# %%
dataset['age'].value_counts().sort_values(ascending=False).head(20).plot(kind="barh")
plt.xlabel("frequency")
plt.ylabel("age")
plt.title("number of people with same age")
plt.show()

# %% [markdown]
# # # Insights / observations
#
# 1. Here people who have age 28 is more
# 2. people with age 23 is less
